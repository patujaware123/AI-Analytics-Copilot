# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df = pd.read_csv(r"C:\Users\prati\OneDrive\Desktop\AI-Analytics-Copilot\data\sales_data.csv")

# %%
df.head()
# Out:
#      Order_ID  Order_Date Customer_ID     Product   Region    Payment_Method  \
# 0  ORD-108925  2024-01-01   CUST-4980       Shoes    South  Cash on Delivery
# 1  ORD-108744  2024-01-01   CUST-1490     T-Shirt    North       Credit Card
# 2  ORD-105049  2024-01-01   CUST-1659  Smartphone    South       Net Banking
# 3  ORD-102440  2024-01-01   CUST-1526     Blender  Central               UPI
# 4  ORD-100869  2024-01-01   CUST-2827  Headphones     East               UPI
#
#   Customer_Type  Quantity        Category  Unit_Price  Discount  Gross_Sales  \
# 0     Returning         4         Fashion        2155       0.0         8620
# 1           VIP         3         Fashion        2247      25.0         6741
# 2           VIP         4     Electronics       36690      25.0       146760
# 3           New         3  Home & Kitchen        6445      15.0        19335
# 4           New         2     Electronics        2896      10.0         5792
#
# ...

# %%
df.shape
# Out:
# (10050, 17)

# %%
df.columns
# Out:
# Index(['Order_ID', 'Order_Date', 'Customer_ID', 'Product', 'Region',
#        'Payment_Method', 'Customer_Type', 'Quantity', 'Category', 'Unit_Price',
#        'Discount', 'Gross_Sales', 'Discount_Amount', 'Sales', 'Cost', 'Profit',
#        'Profit_Margin'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10050 entries, 0 to 10049
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Order_ID         10050 non-null  str
#  1   Order_Date       10050 non-null  str
#  2   Customer_ID      10050 non-null  str
#  3   Product          10050 non-null  str
#  4   Region           10050 non-null  str
#  5   Payment_Method   10050 non-null  str
#  6   Customer_Type    10000 non-null  str
#  7   Quantity         10050 non-null  int64
#  8   Category         10050 non-null  str
#  9   Unit_Price       10050 non-null  int64
#  10  Discount         9948 non-null   float64
#  11  Gross_Sales      10050 non-null  int64
#  12  Discount_Amount  10050 non-null  float64
#  13  Sales            10050 non-null  float64
#  14  Cost             10050 non-null  float64
#  15  Profit           10050 non-null  float64
#  16  Profit_Margin    10050 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# Order_ID             0
# Order_Date           0
# Customer_ID          0
# Product              0
# Region               0
# Payment_Method       0
# Customer_Type       50
# Quantity             0
# Category             0
# Unit_Price           0
# Discount           102
# Gross_Sales          0
# Discount_Amount      0
# Sales                0
# Cost                 0
# Profit               0
# Profit_Margin        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(50)

# %%
df[df.duplicated()].head()
# Out:
#         Order_ID  Order_Date Customer_ID     Product Region    Payment_Method  \
# 506   ORD-104521  2024-02-06   CUST-4629     Blender   East       Net Banking
# 614   ORD-109920  2024-02-14   CUST-4988  Headphones  South        Debit Card
# 782   ORD-105589  2024-02-26   CUST-2772      Tablet  South  Cash on Delivery
# 1103  ORD-109317  2024-03-19   CUST-2869    Keyboard  North        Debit Card
# 1260  ORD-101760  2024-03-30   CUST-4452       Mouse  South       Credit Card
#
#      Customer_Type  Quantity        Category  Unit_Price  Discount  \
# 506            New         3  Home & Kitchen        1978       0.0
# 614            New         4     Electronics       12101      20.0
# 782            VIP         2     Electronics       17414       0.0
# 1103           VIP         2     Electronics        5736       0.0
# 1260           VIP         4     Electronics        1546       5.0
#
#       Gross_Sales  Discount_Amount    Sales      Cost    Profit  Profit_Margin
# ...

# %%
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (10000, 17)

# %%
df[df["Discount"].isnull()].head()
# Out:
#        Order_ID  Order_Date Customer_ID       Product   Region  \
# 22   ORD-107668  2024-01-03   CUST-3806  Coffee Maker     West
# 60   ORD-107502  2024-01-06   CUST-4780      Backpack  Central
# 64   ORD-101592  2024-01-07   CUST-2934       T-Shirt    South
# 83   ORD-101687  2024-01-08   CUST-3161      Keyboard     West
# 115  ORD-102684  2024-01-10   CUST-2646         Jeans  Central
#
#        Payment_Method Customer_Type  Quantity        Category  Unit_Price  \
# 22                UPI     Returning         2  Home & Kitchen       14961
# 60        Credit Card           VIP         3     Accessories        3997
# 64   Cash on Delivery     Returning         1         Fashion        1820
# 83         Debit Card           VIP         5     Electronics         908
# 115       Net Banking           New         2         Fashion        2350
#
#      Discount  Gross_Sales  Discount_Amount    Sales      Cost   Profit  \
# ...

# %%
df[df["Customer_Type"].isnull()].head()
# Out:
#        Order_ID  Order_Date Customer_ID       Product   Region Payment_Method  \
# 102  ORD-100952  2024-01-09   CUST-1357        Laptop  Central     Debit Card
# 218  ORD-105639  2024-01-16   CUST-2920  Coffee Maker    South    Credit Card
# 266  ORD-107079  2024-01-20   CUST-2150  Coffee Maker     West     Debit Card
# 338  ORD-105441  2024-01-25   CUST-4563    Smartwatch     East    Credit Card
# 453  ORD-109748  2024-02-02   CUST-4339    Smartwatch    North    Net Banking
#
#     Customer_Type  Quantity        Category  Unit_Price  Discount  \
# 102           NaN         4     Electronics       78990       0.0
# 218           NaN         3  Home & Kitchen       11266      10.0
# 266           NaN         4  Home & Kitchen       11653       5.0
# 338           NaN         4     Electronics        6719      15.0
# 453           NaN         1     Electronics        2073      20.0
#
#      Gross_Sales  Discount_Amount     Sales       Cost    Profit  \
# ...

# %%
df.dropna()
# Out:
#          Order_ID  Order_Date Customer_ID     Product   Region  \
# 0      ORD-108925  2024-01-01   CUST-4980       Shoes    South
# 1      ORD-108744  2024-01-01   CUST-1490     T-Shirt    North
# 2      ORD-105049  2024-01-01   CUST-1659  Smartphone    South
# 3      ORD-102440  2024-01-01   CUST-1526     Blender  Central
# 4      ORD-100869  2024-01-01   CUST-2827  Headphones     East
# ...           ...         ...         ...         ...      ...
# 10045  ORD-104701  2025-12-31   CUST-2054  Headphones    North
# 10046  ORD-105588  2025-12-31   CUST-4063       Mouse     West
# 10047  ORD-100494  2025-12-31   CUST-4394      Jacket    North
# 10048  ORD-106212  2025-12-31   CUST-1068  Smartphone    South
# 10049  ORD-102689  2025-12-31   CUST-4155       Shoes    North
#
#          Payment_Method Customer_Type  Quantity        Category  Unit_Price  \
# 0      Cash on Delivery     Returning         4         Fashion        2155
# ...

# %%
df[df["Discount"].isnull()].head()
# Out:
#        Order_ID  Order_Date Customer_ID       Product   Region  \
# 22   ORD-107668  2024-01-03   CUST-3806  Coffee Maker     West
# 60   ORD-107502  2024-01-06   CUST-4780      Backpack  Central
# 64   ORD-101592  2024-01-07   CUST-2934       T-Shirt    South
# 83   ORD-101687  2024-01-08   CUST-3161      Keyboard     West
# 115  ORD-102684  2024-01-10   CUST-2646         Jeans  Central
#
#        Payment_Method Customer_Type  Quantity        Category  Unit_Price  \
# 22                UPI     Returning         2  Home & Kitchen       14961
# 60        Credit Card           VIP         3     Accessories        3997
# 64   Cash on Delivery     Returning         1         Fashion        1820
# 83         Debit Card           VIP         5     Electronics         908
# 115       Net Banking           New         2         Fashion        2350
#
#      Discount  Gross_Sales  Discount_Amount    Sales      Cost   Profit  \
# ...

# %%
df[df["Customer_Type"].isnull()].head()
# Out:
#        Order_ID  Order_Date Customer_ID       Product   Region Payment_Method  \
# 102  ORD-100952  2024-01-09   CUST-1357        Laptop  Central     Debit Card
# 218  ORD-105639  2024-01-16   CUST-2920  Coffee Maker    South    Credit Card
# 266  ORD-107079  2024-01-20   CUST-2150  Coffee Maker     West     Debit Card
# 338  ORD-105441  2024-01-25   CUST-4563    Smartwatch     East    Credit Card
# 453  ORD-109748  2024-02-02   CUST-4339    Smartwatch    North    Net Banking
#
#     Customer_Type  Quantity        Category  Unit_Price  Discount  \
# 102           NaN         4     Electronics       78990       0.0
# 218           NaN         3  Home & Kitchen       11266      10.0
# 266           NaN         4  Home & Kitchen       11653       5.0
# 338           NaN         4     Electronics        6719      15.0
# 453           NaN         1     Electronics        2073      20.0
#
#      Gross_Sales  Discount_Amount     Sales       Cost    Profit  \
# ...

# %%
discount_median = df["Discount"].median()

df["Discount"] = df["Discount"].fillna(discount_median)

print("Missing Discount values filled.")
print("Median Discount:", discount_median)
# Out:
# Missing Discount values filled.
# Median Discount: 10.0

# %%
discount_median = df["Discount"].median()

df["Discount"] = df["Discount"].fillna(discount_median)

print("Missing Discount values filled.")
print("Median Discount:", discount_median)
# Out:
# Missing Discount values filled.
# Median Discount: 10.0

# %%
customer_type_mode = df["Customer_Type"].mode()[0]

df["Customer_Type"] = df["Customer_Type"].fillna(customer_type_mode)

print("Missing Customer_Type values filled.")
print("Mode Customer Type:", customer_type_mode)
# Out:
# Missing Customer_Type values filled.
# Mode Customer Type: New

# %%
customer_type_mode = df["Customer_Type"].mode()[0]

df["Customer_Type"] = df["Customer_Type"].fillna(customer_type_mode)

print("Missing Customer_Type values filled.")
print("Mode Customer Type:", customer_type_mode)
# Out:
# Missing Customer_Type values filled.
# Mode Customer Type: New

# %%
print("Missing Values:")
print(df.isnull().sum())

print("\nDuplicate Rows:")
print(df.duplicated().sum())
# Out:
# Missing Values:
# Order_ID           0
# Order_Date         0
# Customer_ID        0
# Product            0
# Region             0
# Payment_Method     0
# Customer_Type      0
# Quantity           0
# Category           0
# Unit_Price         0
# Discount           0
# Gross_Sales        0
# Discount_Amount    0
# Sales              0
# Cost               0
# Profit             0
# Profit_Margin      0
# dtype: int64
#
# Duplicate Rows:
# 0
